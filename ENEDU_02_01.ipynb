# %% [markdown]
# #importar las librerias

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Importamos los datos

# %%
#dataset
inicial=pd.read_stata('2_1_enedu2018_0201_director.dta')

# %%
inicial
# Out:
#          id cod_region           region ccdd departamento ccpp    provincia  \
# 0         1         01         AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS
# 1         2         01         AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS
# 2         3         01         AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS
# 3         4         01         AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS
# 4         5         01         AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS
# ...     ...        ...              ...  ...          ...  ...          ...
# 4065  10038         52  LIMA PROVINCIAS   15         LIMA   10       YAUYOS
# 4066  10042         52  LIMA PROVINCIAS   15         LIMA   10       YAUYOS
# 4067  10043         52  LIMA PROVINCIAS   15         LIMA   10       YAUYOS
# 4068  10044         52  LIMA PROVINCIAS   15         LIMA   10       YAUYOS
# 4069  10048         52  LIMA PROVINCIAS   15         LIMA   10       YAUYOS
#
#      ccdi     distrito  cod_cen_pob  ...    p2_1_05_003_4 p2_1_05_004  \
# 0      01  CHACHAPOYAS       118667  ...              0.0         NaN
# 1      01  CHACHAPOYAS       131197  ...              0.0         NaN
# 2      01  CHACHAPOYAS       131197  ...              0.0        1.sí
# 3      01  CHACHAPOYAS       131197  ...              0.0         NaN
# 4      01  CHACHAPOYAS       131197  ...              0.0         NaN
# ...   ...          ...          ...  ...              ...         ...
# 4065   16      HUANTAN       114760  ...              0.0         NaN
# 4066   19       LINCHA       129540  ...              0.0        2.no
# 4067   24     QUINCHES       126696  ...  4.sin documento         NaN
# 4068   30        TOMAS       110991  ...              0.0         NaN
# 4069   32        VIÑAC       654100  ...              0.0         NaN
#
#      p2_1_05_004_1 p2_1_05_004_2_1 p2_1_05_004_2_2 p2_1_05_004_2_3  \
# 0              NaN             NaN             NaN             NaN
# 1              NaN             NaN             NaN             NaN
# 2             2.no             NaN             NaN             NaN
# 3              NaN             NaN             NaN             NaN
# 4              NaN             NaN             NaN             NaN
# ...            ...             ...             ...             ...
# 4065           NaN             NaN             NaN             NaN
# 4066           NaN             NaN             NaN             NaN
# 4067           NaN             NaN             NaN             NaN
# 4068           NaN             NaN             NaN             NaN
# 4069           NaN             NaN             NaN             NaN
#
#      p2_1_05_005  res_fin_ini   f_ex_dir   f_ex_ini
# 0           2.no   1.completa  11.635157  11.181428
# 1           1.sí   1.completa   1.082340   1.000000
# 2            NaN   1.completa   1.082340   1.000000
# 3           1.sí   1.completa   1.082340   1.000000
# 4            NaN   1.completa   1.338558   1.286359
# ...          ...          ...        ...        ...
# 4065        1.sí   1.completa   2.567706   4.110919
# 4066         NaN   1.completa   2.114582   3.385462
# 4067         NaN   1.completa   3.594789   5.755286
# 4068        1.sí   1.completa   3.594789   5.755286
# 4069        1.sí   1.completa   0.787180   1.984581
#
# [4070 rows x 235 columns]

# %%
#mostramos las columnas que tiene el dataset
inicial.columns
# Out:
# Index(['id', 'cod_region', 'region', 'ccdd', 'departamento', 'ccpp',
#        'provincia', 'ccdi', 'distrito', 'cod_cen_pob',
#        ...
#        'p2_1_05_003_4', 'p2_1_05_004', 'p2_1_05_004_1', 'p2_1_05_004_2_1',
#        'p2_1_05_004_2_2', 'p2_1_05_004_2_3', 'p2_1_05_005', 'res_fin_ini',
#        'f_ex_dir', 'f_ex_ini'],
#       dtype='object', length=235)

# %%
# mostramos la quinta columna del data dataset
inicial.columns[4]
# Out:
# 'departamento'

# %%
#transformamos el objeto inicial en un tipo de lista
list(inicial.columns)
# Out:
# ['id',
#  'cod_region',
#  'region',
#  'ccdd',
#  'departamento',
#  'ccpp',
#  'provincia',
#  'ccdi',
#  'distrito',
#  'cod_cen_pob',
#  'cen_pob',
#  'area',
#  'ruta',
#  'niv_ini_sel',
#  'niv_pri_sel',
#  'niv_sec_sel',
#  'resfin',
#  'det_id',
#  'dir_niv_ini',
#  'dir_niv_pri',
#  'dir_niv_sec',
#  'es_director',
#  'es_docente',
#  'ddir_g_002',
#  'ddir_g_010',
#  'p2_1_01_001_1',
#  'p2_1_01_001_1_1',
#  'p2_1_01_001_2',
#  'p2_1_01_001_1_2',
#  'p2_1_01_001_3',
#  'p2_1_01_001_1_3',
#  'tot_ninos',
#  'p2_1_01_002',
#  'p2_1_01_002_1',
#  'p2_1_01_002_2',
#  'p2_1_01_002_3',
#  'p2_1_01_003',
#  'p2_1_01_003_1',
#  'p2_1_01_003_2',
#  'p2_1_01_003_3',
#  'p2_1_01_003_4',
#  'p2_1_01_003_5',
#  'p2_1_01_003_5_o',
#  'p2_1_01_004',
#  'p2_1_02_001_1_1',
#  'p2_1_02_001_1_2',
#  'p2_1_02_001_1_3',
#  'p2_1_02_001_2_1',
#  'p2_1_02_001_2_2',
#  'p2_1_02_001_2_3',
#  'p2_1_02_002_1',
#  'p2_1_02_002_2',
#  'p2_1_02_002_3',
#  'p2_1_02_002_4',
#  'p2_1_02_002_5',
#  'p2_1_02_002_6',
#  'p2_1_02_002_7',
#  'p2_1_02_002_7_o',
#  'p2_1_02_003_1',
#  'p2_1_02_003_2',
#  'p2_1_02_003_3',
#  'p2_1_02_003_4',
#  'p2_1_02_003_5',
#  'p2_1_02_003_5_o',
#  'p2_1_02_004',
#  'p2_1_02_005_1',
#  'p2_1_02_005_2',
#  'p2_1_02_005_3',
#  'p2_1_02_005_4',
#  'p2_1_02_005_5',
#  'p2_1_02_005_5_o',
#  'p2_1_02_006_1_ini_hora',
#  'p2_1_02_006_1_ini_min',
#  'p2_1_02_006_1_fin_hora',
#  'p2_1_02_006_1_fin_min',
#  'p2_1_02_006_2_1',
#  'p2_1_02_006_2_2',
#  'p2_1_02_006_2_2_1',
#  'p2_1_02_006_2_2_0',
#  'p2_1_02_006_2_3',
#  'p2_1_02_006_2_3_1',
#  'p2_1_02_006_2_3_0',
#  'p2_1_02_006_2_4',
#  'p2_1_02_006_2_4_0',
#  'p2_1_02_011',
#  'p2_1_02_011_1_1',
#  'p2_1_02_011_1_2',
#  'p2_1_02_012',
#  'p2_1_02_012_1',
#  'p2_1_03_002',
#  'p2_1_03_002_1',
#  'p2_1_03_003_1',
#  'p2_1_03_003_2',
#  'p2_1_03_003_3',
#  'p2_1_03_003_4',
#  'p2_1_03_003_4_o',
#  'p2_1_03_003_5',
#  'p2_1_04_001_1_1_1',
#  'p2_1_04_001_1_2_1_3',
#  'p2_1_04_001_1_2_1_4',
#  'p2_1_04_001_1_2_1_5',
#  'p2_1_04_001_1_2_1_6',
#  'p2_1_04_001_1_2_1_7',
#  'p2_1_04_001_1_2_1_8',
#  'p2_1_04_001_1_3_1',
#  'p2_1_04_001_1_1_2',
#  'p2_1_04_001_1_2_2_3',
#  'p2_1_04_001_1_2_2_4',
#  'p2_1_04_001_1_2_2_5',
#  'p2_1_04_001_1_2_2_6',
#  'p2_1_04_001_1_2_2_7',
#  'p2_1_04_001_1_2_2_8',
#  'p2_1_04_001_1_3_2',
#  'p2_1_04_001_1_1_3',
#  'p2_1_04_001_1_2_3_3',
#  'p2_1_04_001_1_2_3_4',
#  'p2_1_04_001_1_2_3_5',
#  'p2_1_04_001_1_2_3_6',
#  'p2_1_04_001_1_2_3_7',
#  'p2_1_04_001_1_2_3_8',
#  'p2_1_04_001_1_3_3',
#  'p2_1_04_001_1_1_4',
#  'p2_1_04_001_1_2_4_3',
#  'p2_1_04_001_1_2_4_4',
#  'p2_1_04_001_1_2_4_5',
#  'p2_1_04_001_1_2_4_6',
#  'p2_1_04_001_1_2_4_7',
#  'p2_1_04_001_1_2_4_8',
#  'p2_1_04_001_1_3_4',
#  'p2_1_04_002_1',
#  'p2_1_04_002_2',
#  'p2_1_04_002_3',
#  'p2_1_04_002_3_o',
#  'p2_1_04_002_4',
#  'p2_1_04_003',
#  'p2_1_04_003_1',
#  'p2_1_04_003_2',
#  'p2_1_04_004_13_1',
#  'p2_1_04_004_1_13_1',
#  'p2_1_04_004_13_2',
#  'p2_1_04_004_1_13_2',
#  'p2_1_04_004_13_3',
#  'p2_1_04_004_1_13_3',
#  'p2_1_04_004_14',
#  'p2_1_04_004_1_14',
#  'p2_1_04_004_14_1',
#  'p2_1_04_004_1_14_1',
#  'p2_1_04_004_15',
#  'p2_1_04_004_1_15',
#  'p2_1_04_004_16',
#  'p2_1_04_004_1_16',
#  'p2_1_04_004_17',
#  'p2_1_04_004_1_17',
#  'p2_1_04_004_18',
#  'p2_1_04_004_1_18',
#  'p2_1_04_004_19',
#  'p2_1_04_004_1_19',
#  'p2_1_04_004_20',
#  'p2_1_04_004_1_20',
#  'p2_1_04_004_21',
#  'p2_1_04_004_1_21',
#  'p2_1_04_004_22',
#  'p2_1_04_004_1_22',
#  'p2_1_04_004_23',
#  'p2_1_04_004_1_23',
#  'p2_1_04_004_24',
#  'p2_1_04_004_1_24',
#  'p2_1_04_004_25',
#  'p2_1_04_004_1_25',
#  'p2_1_04_004_26',
#  'p2_1_04_004_1_26',
#  'p2_1_04_004_27',
#  'p2_1_04_004_1_27',
#  'p2_1_04_004_28',
#  'p2_1_04_004_1_28',
#  'p2_1_04_004_29',
#  'p2_1_04_004_1_29',
#  'p2_1_04_004_30',
#  'p2_1_04_004_1_30',
#  'p2_1_04_004_31',
#  'p2_1_04_004_1_31',
#  'p2_1_04_004_32',
#  'p2_1_04_004_1_32',
#  'p2_1_04_004_33',
#  'p2_1_04_004_1_33',
#  'p2_1_04_004_34',
#  'p2_1_04_004_1_34',
#  'p2_1_04_004_35',
#  'p2_1_04_004_1_35',
#  'p2_1_04_004_36',
#  'p2_1_04_004_1_36',
#  'p2_1_04_004_37',
#  'p2_1_04_004_1_37',
#  'p2_1_04_004_38',
#  'p2_1_04_004_1_38',
#  'p2_1_04_004_39',
#  'p2_1_04_004_1_39',
#  'p2_1_04_004_40',
#  'p2_1_04_004_1_40',
#  'p2_1_04_004_41',
#  'p2_1_04_004_1_41',
#  'p2_1_04_004_42',
#  'p2_1_04_004_1_42',
#  'p2_1_04_004_43',
#  'p2_1_04_004_1_43',
#  'edad_3',
#  'edad_4',
#  'edad_5',
#  'p2_1_05_001_1',
#  'p2_1_05_001_1_1',
#  'p2_1_05_001_2_1',
#  'p2_1_05_001_3_1',
#  'p2_1_05_001_2',
#  'p2_1_05_001_1_2',
#  'p2_1_05_001_2_2',
#  'p2_1_05_001_3_2',
#  'p2_1_05_002_00',
#  'p2_1_05_002_01',
#  'p2_1_05_002_1',
#  'p2_1_05_002_2',
#  'p2_1_05_002_3',
#  'p2_1_05_003_1',
#  'p2_1_05_003_2',
#  'p2_1_05_003_3',
#  'p2_1_05_003_3_o',
#  'p2_1_05_003_4',
#  'p2_1_05_004',
#  'p2_1_05_004_1',
#  'p2_1_05_004_2_1',
#  'p2_1_05_004_2_2',
#  'p2_1_05_004_2_3',
#  'p2_1_05_005',
#  'res_fin_ini',
#  'f_ex_dir',
#  'f_ex_ini']

# %%
# mostramos el tipo de valor
type(inicial.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# operaciones se puede realizar con los datos de la columna
dir(inicial.columns)

# %%
# mostarmos los datos de la columna
inicial['region']
# Out:
# 0              AMAZONAS
# 1              AMAZONAS
# 2              AMAZONAS
# 3              AMAZONAS
# 4              AMAZONAS
#              ...
# 4065    LIMA PROVINCIAS
# 4066    LIMA PROVINCIAS
# 4067    LIMA PROVINCIAS
# 4068    LIMA PROVINCIAS
# 4069    LIMA PROVINCIAS
# Name: region, Length: 4070, dtype: object

# %%
# segunda forma :
inicial.region
# Out:
# 0              AMAZONAS
# 1              AMAZONAS
# 2              AMAZONAS
# 3              AMAZONAS
# 4              AMAZONAS
#              ...
# 4065    LIMA PROVINCIAS
# 4066    LIMA PROVINCIAS
# 4067    LIMA PROVINCIAS
# 4068    LIMA PROVINCIAS
# 4069    LIMA PROVINCIAS
# Name: region, Length: 4070, dtype: object

# %%
# tercera forma utlizando el atributo loc
inicial.loc[:, 'region']
# Out:
# 0              AMAZONAS
# 1              AMAZONAS
# 2              AMAZONAS
# 3              AMAZONAS
# 4              AMAZONAS
#              ...
# 4065    LIMA PROVINCIAS
# 4066    LIMA PROVINCIAS
# 4067    LIMA PROVINCIAS
# 4068    LIMA PROVINCIAS
# 4069    LIMA PROVINCIAS
# Name: region, Length: 4070, dtype: object

# %%
#cuarta forma : utilizando en iloc
inicial.iloc[:, 2]
# Out:
# 0              AMAZONAS
# 1              AMAZONAS
# 2              AMAZONAS
# 3              AMAZONAS
# 4              AMAZONAS
#              ...
# 4065    LIMA PROVINCIAS
# 4066    LIMA PROVINCIAS
# 4067    LIMA PROVINCIAS
# 4068    LIMA PROVINCIAS
# 4069    LIMA PROVINCIAS
# Name: region, Length: 4070, dtype: object

# %% [markdown]
# #Visulalizar mas de una columna

# %%
# método loc
inicial.loc[:, ['departamento','region','provincia','distrito','cen_pob']]
# Out:
#      departamento           region    provincia     distrito  \
# 0        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 1        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 2        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 3        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 4        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# ...           ...              ...          ...          ...
# 4065         LIMA  LIMA PROVINCIAS       YAUYOS      HUANTAN
# 4066         LIMA  LIMA PROVINCIAS       YAUYOS       LINCHA
# 4067         LIMA  LIMA PROVINCIAS       YAUYOS     QUINCHES
# 4068         LIMA  LIMA PROVINCIAS       YAUYOS        TOMAS
# 4069         LIMA  LIMA PROVINCIAS       YAUYOS        VIÑAC
#
#                     cen_pob
# 0                 HIGOSURCO
# 1               CHACHAPOYAS
# 2               CHACHAPOYAS
# 3               CHACHAPOYAS
# 4               CHACHAPOYAS
# ...                     ...
# 4065                  ATCAS
# 4066                   TANA
# 4067  SAN JUAN DE MALLEURAN
# 4068              HUANCACHI
# 4069           SAN JERONIMO
#
# [4070 rows x 5 columns]

# %%
#método iloc
inicial.iloc[:,[4,2,6,8,10]]
# Out:
#      departamento           region    provincia     distrito  \
# 0        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 1        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 2        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 3        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 4        AMAZONAS         AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# ...           ...              ...          ...          ...
# 4065         LIMA  LIMA PROVINCIAS       YAUYOS      HUANTAN
# 4066         LIMA  LIMA PROVINCIAS       YAUYOS       LINCHA
# 4067         LIMA  LIMA PROVINCIAS       YAUYOS     QUINCHES
# 4068         LIMA  LIMA PROVINCIAS       YAUYOS        TOMAS
# 4069         LIMA  LIMA PROVINCIAS       YAUYOS        VIÑAC
#
#                     cen_pob
# 0                 HIGOSURCO
# 1               CHACHAPOYAS
# 2               CHACHAPOYAS
# 3               CHACHAPOYAS
# 4               CHACHAPOYAS
# ...                     ...
# 4065                  ATCAS
# 4066                   TANA
# 4067  SAN JUAN DE MALLEURAN
# 4068              HUANCACHI
# 4069           SAN JERONIMO
#
# [4070 rows x 5 columns]

# %% [markdown]
# #ACCESO A FILAS
# * head
# * tail
# * sample

# %%
# Utilizando el HEAD por defecto muestra las 5 primeras columnas
inicial.head(n =8)
# Out:
#    id cod_region    region ccdd departamento ccpp    provincia ccdi  \
# 0   1         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 1   2         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 2   3         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 3   4         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 4   5         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 5   6         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 6   7         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
# 7  10         01  AMAZONAS   01     AMAZONAS   01  CHACHAPOYAS   01
#
#       distrito  cod_cen_pob  ... p2_1_05_003_4 p2_1_05_004 p2_1_05_004_1  \
# 0  CHACHAPOYAS       118667  ...           0.0         NaN           NaN
# 1  CHACHAPOYAS       131197  ...           0.0         NaN           NaN
# 2  CHACHAPOYAS       131197  ...           0.0        1.sí          2.no
# 3  CHACHAPOYAS       131197  ...           0.0         NaN           NaN
# 4  CHACHAPOYAS       131197  ...           0.0         NaN           NaN
# 5  CHACHAPOYAS       131197  ...           0.0        2.no           NaN
# 6  CHACHAPOYAS       131197  ...           0.0         NaN           NaN
# 7  CHACHAPOYAS       131197  ...           0.0         NaN           NaN
#
#   p2_1_05_004_2_1 p2_1_05_004_2_2 p2_1_05_004_2_3 p2_1_05_005  res_fin_ini  \
# 0             NaN             NaN             NaN        2.no   1.completa
# 1             NaN             NaN             NaN        1.sí   1.completa
# 2             NaN             NaN             NaN         NaN   1.completa
# 3             NaN             NaN             NaN        1.sí   1.completa
# 4             NaN             NaN             NaN         NaN   1.completa
# 5             NaN             NaN             NaN         NaN   1.completa
# 6             NaN             NaN             NaN        1.sí   1.completa
# 7             NaN             NaN             NaN         NaN   1.completa
#
#     f_ex_dir   f_ex_ini
# 0  11.635157  11.181428
# 1   1.082340   1.000000
# 2   1.082340   1.000000
# 3   1.082340   1.000000
# 4   1.338558   1.286359
# 5   2.479624   2.382927
# 6   1.082340   1.000000
# 7   1.082340   1.000000
#
# [8 rows x 235 columns]

# %%
#utlizando TAIL por defecto muestar las 5 ultimas columnas
inicial.tail(n=8)
# Out:
#          id cod_region           region ccdd departamento ccpp provincia ccdi  \
# 4062  10019         52  LIMA PROVINCIAS   15         LIMA   09      OYON   04
# 4063  10028         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   03
# 4064  10034         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   11
# 4065  10038         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   16
# 4066  10042         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   19
# 4067  10043         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   24
# 4068  10044         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   30
# 4069  10048         52  LIMA PROVINCIAS   15         LIMA   10    YAUYOS   32
#
#         distrito  cod_cen_pob  ...    p2_1_05_003_4 p2_1_05_004 p2_1_05_004_1  \
# 4062  COCHAMARCA       549008  ...  4.sin documento        1.sí          2.no
# 4063     ALLAUCA       127871  ...              0.0         NaN           NaN
# 4064     COLONIA       111273  ...              0.0         NaN           NaN
# 4065     HUANTAN       114760  ...              0.0         NaN           NaN
# 4066      LINCHA       129540  ...              0.0        2.no           NaN
# 4067    QUINCHES       126696  ...  4.sin documento         NaN           NaN
# 4068       TOMAS       110991  ...              0.0         NaN           NaN
# 4069       VIÑAC       654100  ...              0.0         NaN           NaN
#
#      p2_1_05_004_2_1 p2_1_05_004_2_2 p2_1_05_004_2_3 p2_1_05_005  res_fin_ini  \
# 4062             NaN             NaN             NaN        1.sí   1.completa
# 4063             NaN             NaN             NaN        2.no   1.completa
# 4064             NaN             NaN             NaN         NaN   1.completa
# 4065             NaN             NaN             NaN        1.sí   1.completa
# 4066             NaN             NaN             NaN         NaN   1.completa
# 4067             NaN             NaN             NaN         NaN   1.completa
# 4068             NaN             NaN             NaN        1.sí   1.completa
# 4069             NaN             NaN             NaN        1.sí   1.completa
#
#       f_ex_dir  f_ex_ini
# 4062  0.971564  8.221837
# 4063  3.994210  6.394762
# 4064  5.991314  9.592143
# 4065  2.567706  4.110919
# 4066  2.114582  3.385462
# 4067  3.594789  5.755286
# 4068  3.594789  5.755286
# 4069  0.787180  1.984581
#
# [8 rows x 235 columns]

# %%
#utlizando  sample por defecto muestra una calumna o fila aleatoria
inicial.sample(n=8)
# Out:
#         id cod_region             region ccdd departamento ccpp    provincia  \
# 2503  6417         18           MOQUEGUA   18     MOQUEGUA   03          ILO
# 1941  4971         13        LA LIBERTAD   13  LA LIBERTAD   02       ASCOPE
# 1163  2944         08              CUSCO   08        CUSCO   05        CANAS
# 1017  2658         07             CALLAO   07       CALLAO   01       CALLAO
# 397    996         03           APURIMAC   03     APURIMAC   02  ANDAHUAYLAS
# 3706  9221         51  PROVINCIA DE LIMA   15         LIMA   01         LIMA
# 1428  3725         10            HUANUCO   10      HUANUCO   01      HUANUCO
# 3942  9741         52    LIMA PROVINCIAS   15         LIMA   05       CAÑETE
#
#      ccdi                 distrito  cod_cen_pob  ... p2_1_05_003_4  \
# 2503   01                      ILO       564531  ...           0.0
# 1941   08              CASA GRANDE       127164  ...           0.0
# 1163   02                   CHECCA       230651  ...           NaN
# 1017   02               BELLAVISTA       523827  ...           0.0
# 397    01              ANDAHUAYLAS       617540  ...           NaN
# 3706   17               LOS OLIVOS       528149  ...           0.0
# 1428   07  SAN FRANCISCO DE CAYRAN       651561  ...           0.0
# 3942   01    SAN VICENTE DE CAÑETE       121146  ...           0.0
#
#      p2_1_05_004 p2_1_05_004_1 p2_1_05_004_2_1 p2_1_05_004_2_2  \
# 2503         NaN           NaN             NaN             NaN
# 1941         NaN           NaN             NaN             NaN
# 1163         NaN           NaN             NaN             NaN
# 1017         NaN           NaN             NaN             NaN
# 397          NaN           NaN             NaN             NaN
# 3706        1.sí          1.sí            21.0             5.0
# 1428         NaN           NaN             NaN             NaN
# 3942         NaN           NaN             NaN             NaN
#
#      p2_1_05_004_2_3 p2_1_05_005  res_fin_ini   f_ex_dir   f_ex_ini
# 2503             NaN        2.no   1.completa   0.793369   1.239038
# 1941             NaN         NaN   1.completa  11.550526  11.966620
# 1163             NaN         NaN   1.completa   5.162861   7.255746
# 1017             NaN         NaN   1.completa   0.936854   1.000000
# 397              NaN         NaN   1.completa   4.777441   5.345378
# 3706          2018.0        1.sí   1.completa   2.116311   1.784766
# 1428             NaN        2.no   1.completa  10.546607  11.471259
# 3942             NaN         NaN   1.completa   1.018232   5.952990
#
# [8 rows x 235 columns]

# %%
#obtener una muestra  de cinco  columnas aleatorias
inicial.sample(n=5 , axis=1)
# Out:
#      p2_1_05_001_2 p2_1_04_001_1_2_1_5 p2_1_04_004_13_3 p2_1_01_003_5  \
# 0             1.sí                2.no             1.sí           NaN
# 1             1.sí                2.no             1.sí           0.0
# 2             1.sí                2.no             1.sí           0.0
# 3             1.sí                1.sí             1.sí           0.0
# 4             1.sí                2.no             1.sí           0.0
# ...            ...                 ...              ...           ...
# 4065          1.sí                2.no             1.sí           NaN
# 4066          1.sí                2.no             1.sí           NaN
# 4067          1.sí                2.no             1.sí           NaN
# 4068          1.sí                2.no             1.sí           NaN
# 4069          1.sí                2.no             1.sí           0.0
#
#                     cen_pob
# 0                 HIGOSURCO
# 1               CHACHAPOYAS
# 2               CHACHAPOYAS
# 3               CHACHAPOYAS
# 4               CHACHAPOYAS
# ...                     ...
# 4065                  ATCAS
# 4066                   TANA
# 4067  SAN JUAN DE MALLEURAN
# 4068              HUANCACHI
# 4069           SAN JERONIMO
#
# [4070 rows x 5 columns]

# %% [markdown]
# #TIPO DE DATOS DE LAS COLUMNAS

# %%
inicial.dtypes
# Out:
# id                    int16
# cod_region           object
# region               object
# ccdd                 object
# departamento         object
#                      ...
# p2_1_05_004_2_3     float64
# p2_1_05_005        category
# res_fin_ini        category
# f_ex_dir            float32
# f_ex_ini            float32
# Length: 235, dtype: object

# %% [markdown]
# #Anilisís unidimensional

# %%
inicial.ddir_g_010
# Out:
# 0         1.nombrado
# 1         1.nombrado
# 2         1.nombrado
# 3         1.nombrado
# 4         1.nombrado
#             ...
# 4065    2.contratado
# 4066      1.nombrado
# 4067    2.contratado
# 4068      1.nombrado
# 4069      1.nombrado
# Name: ddir_g_010, Length: 4070, dtype: category
# Categories (2, object): ['1.nombrado' < '2.contratado']

# %%
# cuales son los posibles valores en la columna aplicando el método uniquie
inicial.ddir_g_010.unique()
# Out:
# ['1.nombrado', '2.contratado']
# Categories (2, object): ['1.nombrado' < '2.contratado']

# %%
#cuantos valores hay para cada valor  de la una columna en especifico
inicial.ddir_g_010.value_counts()
# Out:
# ddir_g_010
# 1.nombrado      2957
# 2.contratado    1113
# Name: count, dtype: int64

# %%
# mostrar el valor anterior en porcentaje
inicial['ddir_g_010'].value_counts()*100/inicial.shape[0]
# Out:
# ddir_g_010
# 1.nombrado      72.653563
# 2.contratado    27.346437
# Name: count, dtype: float64

# %%
inicial['area'].value_counts()
# Out:
# area
# urbana    2423
# rural     1647
# Name: count, dtype: int64

# %%
#con porcentaje
inicial['area'].value_counts()*100/inicial.shape[0]
# Out:
# area
# urbana    59.53317
# rural     40.46683
# Name: count, dtype: float64

# %%
# mostar los datos de la culumna p2_1_02_006_2_1
inicial.iloc[:, 75]
# Out:
# 0       30
# 1       30
# 2       15
# 3       20
# 4       30
#         ..
# 4065    20
# 4066    30
# 4067    30
# 4068    15
# 4069    30
# Name: p2_1_02_006_2_1, Length: 4070, dtype: int8

# %%
#contamos los valores
inicial.iloc[:, 75].unique()
# Out:
# array([30, 15, 20, 10, 25], dtype=int8)

# %%
#mostrar los valores por cada categoría
inicial.iloc[:,75].value_counts()
# Out:
# p2_1_02_006_2_1
# 30    2096
# 15     868
# 20     835
# 25     138
# 10     133
# Name: count, dtype: int64

# %%
#mostramos en porcentajes
inicial.iloc[:,75].value_counts()*100/inicial.shape[0]
# Out:
# p2_1_02_006_2_1
# 30    51.498771
# 15    21.326781
# 20    20.515971
# 25     3.390663
# 10     3.267813
# Name: count, dtype: float64

# %%
#ordenamos de forma ascendente el cálculo de la celda anterior
inicial.iloc[:,75].value_counts().sort_index()
# Out:
# p2_1_02_006_2_1
# 10     133
# 15     868
# 20     835
# 25     138
# 30    2096
# Name: count, dtype: int64

# %%
#ordenamos de forma descendente el cálculo de la columna p2_1_02_006_2_1
inicial.iloc[:,75].value_counts().sort_index(ascending=False)
# Out:
# p2_1_02_006_2_1
# 30    2096
# 25     138
# 20     835
# 15     868
# 10     133
# Name: count, dtype: int64

# %%
# mostrar los valores con porcentaje de forma descendentes
inicial.iloc[:,75].value_counts().sort_index(ascending=False)*100/inicial.shape[0]
# Out:
# p2_1_02_006_2_1
# 30    51.498771
# 25     3.390663
# 20    20.515971
# 15    21.326781
# 10     3.267813
# Name: count, dtype: float64

# %% [markdown]
# #ANALISÍS BUIDIMENCIONAL
# * Departamento
# * P2_1_02_006_2_1

# %%
#mostra el número de departameto
inicial.departamento.unique()
# Out:
# array(['AMAZONAS', 'ANCASH', 'APURIMAC', 'AREQUIPA', 'AYACUCHO',
#        'CAJAMARCA', 'CALLAO', 'CUSCO', 'HUANCAVELICA', 'HUANUCO', 'ICA',
#        'JUNIN', 'LA LIBERTAD', 'LAMBAYEQUE', 'LORETO', 'MADRE DE DIOS',
#        'MOQUEGUA', 'PASCO', 'PIURA', 'PUNO', 'SAN MARTIN', 'TACNA',
#        'TUMBES', 'UCAYALI', 'LIMA'], dtype=object)

# %%
inicial.iloc[:,4].unique().size
# Out:
# 25

# %%
#Distribución del número de minutos de recreo del departamento Puno
inicial.loc[inicial.departamento == 'PUNO', 'p2_1_02_006_2_1']
# Out:
# 2820    15
# 2821    30
# 2822    15
# 2823    30
# 2824    15
#         ..
# 2995    30
# 2996    30
# 2997    15
# 2998    15
# 2999    15
# Name: p2_1_02_006_2_1, Length: 180, dtype: int8

# %%
# calculamos el tiempo promedio en minutos de la duración de recreo en el departameto de PUNO
inicial.loc[inicial.departamento=='PUNO', 'p2_1_02_006_2_1']. mean()
# Out:
# 21.77777777777778

# %%
puno_recreo = inicial.loc[inicial.departamento=='PUNO', 'p2_1_02_006_2_1'].value_counts().rename_axis('Horas de Recreo')
display(puno_recreo)
# Out:
# Horas de Recreo
# 30    75
# 15    70
# 20    21
# 10    10
# 25     4
# Name: count, dtype: int64

# %%
#mostrar la distribución de minutos de duración del recreo en el departamento de LA LIBERTAD
NunFilas_Lib=inicial.loc[inicial.departamento=='LA LIBERTAD', 'p2_1_02_006_2_1'].shape[0]
inicial.loc[inicial.departamento=='LA LIBERTAD', 'p2_1_02_006_2_1'].value_counts().sort_index(ascending=False)*100/NunFilas_Lib
# Out:
# p2_1_02_006_2_1
# 30    32.926829
# 25     2.439024
# 20    20.121951
# 15    40.853659
# 10     3.658537
# Name: count, dtype: float64

# %%
#mostrar en gráfica de barra
PunoMin_recreo=inicial.loc[inicial.departamento=='LA LIBERTAD', 'p2_1_02_006_2_1'].value_counts().sort_index(ascending=False)*100/NunFilas_Puno
PunoMin_recreo.plot(kind='bar')
plt.title('LA LIBERTAD')
plt.xlabel('Minutos de recreo')
plt.show()

# %% [markdown]
# #EJERCICIO
# * Costruir una driagram ade barras para cada departamento
# * Guardar la imagen en una carpeta

# %%
os.makedirs('diagramar_baras')

# %%
os.chdir('diagramar_baras')

# %%
#al cometer un error borramos el archivo
os.chdir('/content/')
os.system('rm -rf diagramar_baras')
os.listdir
# Out:
# <function posix.listdir(path=None)>

# %%
for dpto in inicial.departamento.unique():
  NunFilas_Puno=inicial.loc[inicial.departamento==dpto, 'p2_1_02_006_2_1'].shape[0]
  PunoMin_recreo=inicial.loc[inicial.departamento==dpto, 'p2_1_02_006_2_1'].value_counts().sort_index(ascending=False)*100/NunFilas_Puno
  PunoMin_recreo.plot(kind='bar')
  plt.title(dpto)
  plt.xlabel('Minutos de recreo')
  plt.savefig('Departamento' + dpto + '.png')
  plt.show()

# %%
#mostrar los valores de la columna departamento
inicial['departamento']
# Out:
# 0       AMAZONAS
# 1       AMAZONAS
# 2       AMAZONAS
# 3       AMAZONAS
# 4       AMAZONAS
#           ...
# 4065        LIMA
# 4066        LIMA
# 4067        LIMA
# 4068        LIMA
# 4069        LIMA
# Name: departamento, Length: 4070, dtype: object

# %%
for region in inicial.region.unique():

  filas=inicial.loc[inicial.region==region, 'p2_1_02_006_2_1'].shape[0]
  region_recreo=inicial.loc[inicial.region==region, 'p2_1_02_006_2_1' ].value_counts().sort_index(ascending=False)*100/filas
  region_recreo.plot(kind='bar')
  plt.title(region)
  plt.xlabel('Minutos de recreo')
  plt.ylabel('porcentaje de colegios')
  plt.legend()
  plt.show()

# %%
#mostar la cantidad de colegio del distrio de Taurija, Pataz, La Laibertad

filas=inicial[(inicial['region']=='LA LIBERTAD') & (inicial['provincia']=='PATAZ') & (inicial['distrito'] =='TAURIJA') ]
filas[['region', 'provincia', 'distrito']]
# Out:
#            region provincia distrito
# 1991  LA LIBERTAD     PATAZ  TAURIJA

# %%
#Mostrar la distruibución de  las horas de recreo de  la proovincia de Pataz región La Libertad
filas=inicial[(inicial['region']=='LA LIBERTAD') & (inicial['provincia']=='PATAZ')]
filas[['region', 'provincia', 'distrito', 'p2_1_02_006_2_1']]

# %%
# mostrar la columna sexo de los directores
inicial.loc[inicial.es_director==1,'ddir_g_002'].value_counts()
# Out:
# ddir_g_002
# 2.femenino     3458
# 1.masculino     612
# Name: count, dtype: int64

# %%
director_sexo=inicial.loc[inicial.es_director==1, 'ddir_g_002'].value_counts()
director_sexo.plot(kind='bar')
plt.title('Cantidad de direciores por sexo')
plt.xlabel('SeXO')
plt.ylabel('Cantidad')
plt.show()

# %%
director_sexo = inicial.loc[inicial.es_director == 1, 'ddir_g_002'].value_counts()
colors = sns.color_palette("husl", len(director_sexo))

# Crear el gráfico de barras
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(director_sexo.index, director_sexo.values, color=colors)

# Agregar las cantidades encima de cada barra
for bar, value in zip(bars, director_sexo.values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(value), ha='center', va='bottom', fontsize=10, color='black')

# Personalización del gráfico
ax.set_title('Cantidad de Directores por Sexo', fontsize=14)
ax.set_xlabel('Sexo', fontsize=12)
ax.set_ylabel('Cantidad', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
#Sexo docente
inicial.loc[inicial.es_docente==0, 'ddir_g_002'].value_counts()
# Out:
# ddir_g_002
# 2.femenino     1066
# 1.masculino     500
# Name: count, dtype: int64

# %%
#docentes que son directores
inicial['es_docente'].value_counts()
# Out:
# es_docente
# 1    2504
# 0    1566
# Name: count, dtype: int64

# %%
director_docente = inicial.loc[(inicial['es_director'] == 1, 'es_docente')].value_counts()
colors = ['#8FBC8F', '#5F9EA0']
nombre_columna = ['Si', 'No']
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(director_docente.index, director_docente.values, color=colors, label=nombre_columna)
ax.set_xticklabels(director_docente.index, color='black', fontsize=12)

for bar, value, in zip(bars, director_docente.values, ):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(value), ha='center', va='bottom', fontsize=10, color='black')

ax.set_title('Cantidad de Docentes que son Directores', fontsize=14)
ax.set_xlabel('Docencia', fontsize=12)
ax.set_ylabel('Cantidad', fontsize=12)
ax.legend()
plt.show()
# Out:
# <ipython-input-30-3930027aa10e>:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(director_docente.index, color='black', fontsize=12)

# %%
recreo_horas = inicial['p2_1_02_006_2_1'].value_counts()

data = recreo_horas.values
labels = recreo_horas.index

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} colegios)"

fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, labels,
          title="Horas de Recreo",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=10, weight="bold")
ax.set_title("Distribución de Horas de Recreo", fontsize=14)

plt.show()
